# %%
# !pip install -q "numpy==2.0.2" "pandas==2.2.2" "chess==1.11.2" "scikit-learn==1.6.1" "joblib==1.5.2" "tqdm==4.67.1" "scipy==1.13.1"

# %%
import numpy, pandas, torch, sklearn, chess
print(numpy.__version__, pandas.__version__, torch.__version__)

# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# %cd /content/drive/MyDrive/chess

# %%
# !python cnn_train.py
